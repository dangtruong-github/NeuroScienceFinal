# %%
import os
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset
import mne
import numpy as np

# %% [markdown]
# ## 1. Custom Pytorch dataset

# %%
class NeuronAgeDataset(Dataset):
    def __init__(self, csv_file, data_dir, segment_duration=5, overlap=0.5):
        self.df = pd.read_csv(csv_file, sep='\t')
        self.data_dir = data_dir
        self.segment_duration = segment_duration
        self.overlap = overlap
        self.sfreq = None
        self.segments = []
        self.labels = []
        self._prepare_data()

    def _prepare_data(self):
        for idx, row in self.df.iterrows():
            age = row['age']
            rawdata_path_prefix = row['participant_id']
            rawdata_path = os.path.join(self.data_dir, f'{rawdata_path_prefix}_sflip_parc-raw.fif')
            try:
                rawdata = mne.io.read_raw_fif(rawdata_path, preload=True)
            except Exception as e:
                print(f"An error occurred while loading the file: {e}")
                continue
            
            if self.sfreq is None:
                self.sfreq = rawdata.info['sfreq']
            
            bad_segments = []
            for annot in rawdata.annotations:
                if "bad_segment" in annot['description']:
                    start = annot['onset']
                    end = start + annot['duration']
                    bad_segments.append((start, end))
            
            segment_samples = int(self.segment_duration * self.sfreq) # number of timesteps in a segment
            overlap_samples = int(self.overlap * segment_samples) # number of overlapping timesteps between segments
            total_samples = len(rawdata.times) # total number of timesteps in the raw data
            print(f'segment samples: {segment_samples}')
            print(f"Total samples: {total_samples}")


            start_sample = 0
            while start_sample + segment_samples <= total_samples:
                end_sample = start_sample + segment_samples
                segment_times = rawdata.times[start_sample:end_sample]
                
                if not any(start <= t <= end for t in segment_times for start, end in bad_segments):
                    data, _ = rawdata[:52, start_sample:end_sample]
                    self.segments.append(data)
                    self.labels.append(age)
                
                start_sample += segment_samples - overlap_samples

    def __len__(self):
        return len(self.segments)

    def __getitem__(self, idx):
        segment = self.segments[idx]
        label = self.labels[idx]
        return torch.tensor(segment, dtype=torch.float32), torch.tensor(label, dtype=torch.float32)

# %% [markdown]
# ## 2. EEG net

# %%
class EEGNet(nn.Module):
    def __init__(self):
        super(EEGNet, self).__init__()
        self.T = 120
        
        # Layer 1
        self.conv1 = nn.Conv2d(1, 16, (1, 52), padding = 0)
        self.batchnorm1 = nn.BatchNorm2d(16, False)
        
        # Layer 2
        self.padding1 = nn.ZeroPad2d((16, 17, 0, 1))
        self.conv2 = nn.Conv2d(1, 4, (2, 32))
        self.batchnorm2 = nn.BatchNorm2d(4, False)
        self.pooling2 = nn.MaxPool2d(2, 4)
        
        # Layer 3
        self.padding2 = nn.ZeroPad2d((2, 1, 4, 3))
        self.conv3 = nn.Conv2d(4, 4, (8, 4))
        self.batchnorm3 = nn.BatchNorm2d(4, False)
        self.pooling3 = nn.MaxPool2d((2, 4))
        
        # FC Layer
        # NOTE: This dimension will depend on the number of timestamps per sample in your data.
        # I have 120 timepoints. 
        self.fc1 = nn.Linear(376, 1)
        

    def forward(self, x):
        """
        (batch_size, 1, num_timepoints, num_channels) -> (batch_size, 1)
        """
        batch_size = x.size(0)
        # Layer 1
        x = F.elu(self.conv1(x)) # -> (batch_size, 16, num_timepoints, 1)
        x = self.batchnorm1(x) # -> (batch_size, 16, num_timepoints, 1)
        x = F.dropout(x, 0.25) # -> (batch_size, 16, num_timepoints, 1)
        x = x.permute(0, 3, 1, 2) # -> (batch_size, 1, num_timepoints, 16)
        
        # Layer 2
        x = self.padding1(x) # -> (batch_size, 1, num_timepoints, 33)
        x = F.elu(self.conv2(x)) # -> (batch_size, 4, num_timepoints, 1)
        x = self.batchnorm2(x) # -> (batch_size, 4, num_timepoints, 1)
        x = F.dropout(x, 0.25) # -> (batch_size, 4, num_timepoints, 1)
        x = self.pooling2(x) # -> (batch_size, 4, num_timepoints//2, 1)
        
        # Layer 3
        x = self.padding2(x)
        x = F.elu(self.conv3(x))
        x = self.batchnorm3(x)
        x = F.dropout(x, 0.25)
        x = self.pooling3(x)

        # FC Layer
        x = x.reshape(batch_size, 376)
        x = F.sigmoid(self.fc1(x))
        return x # -> (batch_size, 1)

# %% [markdown]
# ## 3. Run baseline

# %%
data_dir = 'data/raw'
train_csv_file = 'data/train_set.csv'
test_csv_file = 'data/test_set.csv'
train_dataset = NeuronAgeDataset(train_csv_file, data_dir, segment_duration=3, overlap=0.5)
test_dataset = NeuronAgeDataset(test_csv_file, data_dir, segment_duration=3, overlap=0.5)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=256, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=256, shuffle=True)
# Out:
# Opening raw data file data/raw/sub-CC320089_sflip_parc-raw.fif...
#     Range : 23000 ... 163499 =     92.000 ...   653.996 secs
# Ready.
# Reading 0 ... 140499  =      0.000 ...   561.996 secs...
# segment samples: 750
# Total samples: 140500
# Opening raw data file data/raw/sub-CC520209_sflip_parc-raw.fif...
#     Range : 37750 ... 178249 =    151.000 ...   712.996 secs
# Ready.
# Reading 0 ... 140499  =      0.000 ...   561.996 secs...
# segment samples: 750
# Total samples: 140500
# Opening raw data file data/raw/sub-CC110045_sflip_parc-raw.fif...
#     Range : 24000 ... 164499 =     96.000 ...   657.996 secs
# Ready.
# Reading 0 ... 140499  =      0.000 ...   561.996 secs...
# segment samples: 750
# Total samples: 140500
# Opening raw data file data/raw/sub-CC610052_sflip_parc-raw.fif...
#     Range : 23000 ... 163999 =     92.000 ...   655.996 secs
# Ready.
# Reading 0 ... 140999  =      0.000 ...   563.996 secs...
# segment samples: 750
# Total samples: 141000
# Opening raw data file data/raw/sub-CC221031_sflip_parc-raw.fif...
#     Range : 4500 ... 145249 =     18.000 ...   580.996 secs
# Ready.
# Reading 0 ... 140749  =      0.000 ...   562.996 secs...
# segment samples: 750
# Total samples: 140750
# Opening raw data file data/raw/sub-CC220223_sflip_parc-raw.fif...
#     Range : 8000 ... 149249 =     32.000 ...   596.996 secs
# Ready.
# Reading 0 ... 141249  =      0.000 ...   564.996 secs...
# segment samples: 750
# Total samples: 141250
# Opening raw data file data/raw/sub-CC321281_sflip_parc-raw.fif...
#     Range : 7750 ... 174249 =     31.000 ...   696.996 secs
# Ready.
# Reading 0 ... 166499  =      0.000 ...   665.996 secs...
# segment samples: 750
# Total samples: 166500
# Opening raw data file data/raw/sub-CC420143_sflip_parc-raw.fif...
#     Range : 39000 ... 179749 =    156.000 ...   718.996 secs
# Ready.
# Reading 0 ... 140749  =      0.000 ...   562.996 secs...
# segment samples: 750
# Total samples: 140750
# Opening raw data file data/raw/sub-CC120347_sflip_parc-raw.fif...
#     Range : 13250 ... 154249 =     53.000 ...   616.996 secs
# Ready.
# Reading 0 ... 140999  =      0.000 ...   563.996 secs...
# segment samples: 750
# Total samples: 141000
# Opening raw data file data/raw/sub-CC710088_sflip_parc-raw.fif...
#     Range : 31500 ... 171999 =    126.000 ...   687.996 secs
# Ready.
# Reading 0 ... 140499  =      0.000 ...   561.996 secs...
# segment samples: 750
# Total samples: 140500
# Opening raw data file data/raw/sub-CC410129_sflip_parc-raw.fif...
#     Range : 10500 ... 151249 =     42.000 ...   604.996 secs
# Ready.
# Reading 0 ... 140749  =      0.000 ...   562.996 secs...
# segment samples: 750
# Total samples: 140750
# Opening raw data file data/raw/sub-CC420454_sflip_parc-raw.fif...
#     Range : 19000 ... 159749 =     76.000 ...   638.996 secs
# Ready.
# Reading 0 ... 140749  =      0.000 ...   562.996 secs...
# segment samples: 750
# Total samples: 140750
# Opening raw data file data/raw/sub-CC720119_sflip_parc-raw.fif...
#     Range : 74500 ... 210249 =    298.000 ...   840.996 secs
# Ready.
# Reading 0 ... 135749  =      0.000 ...   542.996 secs...
# segment samples: 750
# Total samples: 135750
# Opening raw data file data/raw/sub-CC210051_sflip_parc-raw.fif...
#     Range : 12500 ... 153499 =     50.000 ...   613.996 secs
# Ready.
# Reading 0 ... 140999  =      0.000 ...   563.996 secs...
# segment samples: 750
# Total samples: 141000
# Opening raw data file data/raw/sub-CC410097_sflip_parc-raw.fif...
#     Range : 48750 ... 189499 =    195.000 ...   757.996 secs
# Ready.
# Reading 0 ... 140749  =      0.000 ...   562.996 secs...
# segment samples: 750
# Total samples: 140750
# Opening raw data file data/raw/sub-CC120182_sflip_parc-raw.fif...
#     Range : 33750 ... 174499 =    135.000 ...   697.996 secs
# Ready.
# Reading 0 ... 140749  =      0.000 ...   562.996 secs...
# segment samples: 750
# Total samples: 140750
# Opening raw data file data/raw/sub-CC711244_sflip_parc-raw.fif...
#     Range : 33750 ... 174249 =    135.000 ...   696.996 secs
# Ready.
# Reading 0 ... 140499  =      0.000 ...   561.996 secs...
# segment samples: 750
# Total samples: 140500
# Opening raw data file data/raw/sub-CC321107_sflip_parc-raw.fif...
#     Range : 20000 ... 162749 =     80.000 ...   650.996 secs
# Ready.
# Reading 0 ... 142749  =      0.000 ...   570.996 secs...
# segment samples: 750
# Total samples: 142750
# Opening raw data file data/raw/sub-CC520200_sflip_parc-raw.fif...
#     Range : 60750 ... 201249 =    243.000 ...   804.996 secs
# Ready.
# Reading 0 ... 140499  =      0.000 ...   561.996 secs...
# segment samples: 750
# Total samples: 140500
# Opening raw data file data/raw/sub-CC110187_sflip_parc-raw.fif...
#     Range : 19000 ... 159999 =     76.000 ...   639.996 secs
# Ready.
# Reading 0 ... 140999  =      0.000 ...   563.996 secs...
# segment samples: 750
# Total samples: 141000
# Opening raw data file data/raw/sub-CC320687_sflip_parc-raw.fif...
#     Range : 12750 ... 153749 =     51.000 ...   614.996 secs
# Ready.
# Reading 0 ... 140999  =      0.000 ...   563.996 secs...
# segment samples: 750
# Total samples: 141000
# Opening raw data file data/raw/sub-CC410251_sflip_parc-raw.fif...
#     Range : 27750 ... 170499 =    111.000 ...   681.996 secs
# Ready.
# Reading 0 ... 142749  =      0.000 ...   570.996 secs...
# segment samples: 750
# Total samples: 142750
# Opening raw data file data/raw/sub-CC110098_sflip_parc-raw.fif...
#     Range : 10750 ... 151749 =     43.000 ...   606.996 secs
# Ready.
# Reading 0 ... 140999  =      0.000 ...   563.996 secs...
# segment samples: 750
# Total samples: 141000
# Opening raw data file data/raw/sub-CC120409_sflip_parc-raw.fif...
#     Range : 8000 ... 148499 =     32.000 ...   593.996 secs
# Ready.
# Reading 0 ... 140499  =      0.000 ...   561.996 secs...
# segment samples: 750
# Total samples: 140500
# Opening raw data file data/raw/sub-CC410015_sflip_parc-raw.fif...
#     Range : 23750 ... 164249 =     95.000 ...   656.996 secs
# Ready.
# Reading 0 ... 140499  =      0.000 ...   561.996 secs...
# segment samples: 750
# Total samples: 140500
# Opening raw data file data/raw/sub-CC710313_sflip_parc-raw.fif...
#     Range : 5750 ... 147999 =     23.000 ...   591.996 secs
# Ready.
# Reading 0 ... 142249  =      0.000 ...   568.996 secs...
# segment samples: 750
# Total samples: 142250
# Opening raw data file data/raw/sub-CC610210_sflip_parc-raw.fif...
#     Range : 4750 ... 145749 =     19.000 ...   582.996 secs
# Ready.
# Reading 0 ... 140999  =      0.000 ...   563.996 secs...
# segment samples: 750
# Total samples: 141000
# Opening raw data file data/raw/sub-CC220115_sflip_parc-raw.fif...
#     Range : 7750 ... 148249 =     31.000 ...   592.996 secs
# Ready.
# Reading 0 ... 140499  =      0.000 ...   561.996 secs...
# segment samples: 750
# Total samples: 140500
# Opening raw data file data/raw/sub-CC110069_sflip_parc-raw.fif...
#     Range : 16500 ... 156999 =     66.000 ...   627.996 secs
# Ready.
# Reading 0 ... 140499  =      0.000 ...   561.996 secs...
# segment samples: 750
# Total samples: 140500
# Opening raw data file data/raw/sub-CC620685_sflip_parc-raw.fif...
#     Range : 37500 ... 198249 =    150.000 ...   792.996 secs
# Ready.
# Reading 0 ... 160749  =      0.000 ...   642.996 secs...
# segment samples: 750
# Total samples: 160750
# Opening raw data file data/raw/sub-CC121479_sflip_parc-raw.fif...
#     Range : 28500 ... 170249 =    114.000 ...   680.996 secs
# Ready.
# Reading 0 ... 141749  =      0.000 ...   566.996 secs...
# segment samples: 750
# Total samples: 141750
# Opening raw data file data/raw/sub-CC610392_sflip_parc-raw.fif...
#     Range : 31750 ... 172249 =    127.000 ...   688.996 secs
# Ready.
# Reading 0 ... 140499  =      0.000 ...   561.996 secs...
# segment samples: 750
# Total samples: 140500
# Opening raw data file data/raw/sub-CC620499_sflip_parc-raw.fif...
#     Range : 13750 ... 154249 =     55.000 ...   616.996 secs
# Ready.
# Reading 0 ... 140499  =      0.000 ...   561.996 secs...
# segment samples: 750
# Total samples: 140500
# Opening raw data file data/raw/sub-CC321174_sflip_parc-raw.fif...
#     Range : 65250 ... 206249 =    261.000 ...   824.996 secs
# Ready.
# Reading 0 ... 140999  =      0.000 ...   563.996 secs...
# segment samples: 750
# Total samples: 141000
# Opening raw data file data/raw/sub-CC110182_sflip_parc-raw.fif...
#     Range : 19000 ... 159499 =     76.000 ...   637.996 secs
# Ready.
# Reading 0 ... 140499  =      0.000 ...   561.996 secs...
# segment samples: 750
# Total samples: 140500
# Opening raw data file data/raw/sub-CC420396_sflip_parc-raw.fif...
#     Range : 6250 ... 148999 =     25.000 ...   595.996 secs
# Ready.
# Reading 0 ... 142749  =      0.000 ...   570.996 secs...
# segment samples: 750
# Total samples: 142750
# Opening raw data file data/raw/sub-CC510548_sflip_parc-raw.fif...
#     Range : 4500 ... 144499 =     18.000 ...   577.996 secs
# Ready.
# Reading 0 ... 139999  =      0.000 ...   559.996 secs...
# segment samples: 750
# Total samples: 140000
# Opening raw data file data/raw/sub-CC110033_sflip_parc-raw.fif...
#     Range : 16750 ... 160249 =     67.000 ...   640.996 secs
# Ready.
# Reading 0 ... 143499  =      0.000 ...   573.996 secs...
# segment samples: 750
# Total samples: 143500
# Opening raw data file data/raw/sub-CC610039_sflip_parc-raw.fif...
#     Range : 24500 ... 168499 =     98.000 ...   673.996 secs
# Ready.
# Reading 0 ... 143999  =      0.000 ...   575.996 secs...
# segment samples: 750
# Total samples: 144000
# Opening raw data file data/raw/sub-CC512003_sflip_parc-raw.fif...
#     Range : 22250 ... 162999 =     89.000 ...   651.996 secs
# Ready.
# Reading 0 ... 140749  =      0.000 ...   562.996 secs...
# segment samples: 750
# Total samples: 140750
# Opening raw data file data/raw/sub-CC320575_sflip_parc-raw.fif...
#     Range : 17000 ... 157749 =     68.000 ...   630.996 secs
# Ready.
# Reading 0 ... 140749  =      0.000 ...   562.996 secs...
# segment samples: 750
# Total samples: 140750
# Opening raw data file data/raw/sub-CC220843_sflip_parc-raw.fif...
#     Range : 20000 ... 161249 =     80.000 ...   644.996 secs
# Ready.
# Reading 0 ... 141249  =      0.000 ...   564.996 secs...
# segment samples: 750
# Total samples: 141250
# Opening raw data file data/raw/sub-CC410287_sflip_parc-raw.fif...
#     Range : 11750 ... 152749 =     47.000 ...   610.996 secs
# Ready.
# Reading 0 ... 140999  =      0.000 ...   563.996 secs...
# segment samples: 750
# Total samples: 141000
# Opening raw data file data/raw/sub-CC120469_sflip_parc-raw.fif...
#     Range : 10000 ... 152249 =     40.000 ...   608.996 secs
# Ready.
# Reading 0 ... 142249  =      0.000 ...   568.996 secs...
# segment samples: 750
# Total samples: 142250
# Opening raw data file data/raw/sub-CC210422_sflip_parc-raw.fif...
#     Range : 18000 ... 158499 =     72.000 ...   633.996 secs
# Ready.
# Reading 0 ... 140499  =      0.000 ...   561.996 secs...
# segment samples: 750
# Total samples: 140500
# Opening raw data file data/raw/sub-CC520002_sflip_parc-raw.fif...
#     Range : 30000 ... 171249 =    120.000 ...   684.996 secs
# Ready.
# Reading 0 ... 141249  =      0.000 ...   564.996 secs...
# segment samples: 750
# Total samples: 141250
# Opening raw data file data/raw/sub-CC120264_sflip_parc-raw.fif...
#     Range : 15750 ... 156249 =     63.000 ...   624.996 secs
# Ready.
# Reading 0 ... 140499  =      0.000 ...   561.996 secs...
# segment samples: 750
# Total samples: 140500
# Opening raw data file data/raw/sub-CC120208_sflip_parc-raw.fif...
#     Range : 4750 ... 145499 =     19.000 ...   581.996 secs
# Ready.
# Reading 0 ... 140749  =      0.000 ...   562.996 secs...
# segment samples: 750
# Total samples: 140750
# Opening raw data file data/raw/sub-CC520480_sflip_parc-raw.fif...
#     Range : 4000 ... 144749 =     16.000 ...   578.996 secs
# Ready.
# Reading 0 ... 140749  =      0.000 ...   562.996 secs...
# segment samples: 750
# Total samples: 140750
# Opening raw data file data/raw/sub-CC410084_sflip_parc-raw.fif...
#     Range : 37250 ... 222499 =    149.000 ...   889.996 secs
# Ready.
# Reading 0 ... 185249  =      0.000 ...   740.996 secs...
# An error occurred while loading the file: buffer size must be a multiple of element size
# Opening raw data file data/raw/sub-CC210172_sflip_parc-raw.fif...
#     Range : 4500 ... 145499 =     18.000 ...   581.996 secs
# Ready.
# Reading 0 ... 140999  =      0.000 ...   563.996 secs...
# /tmp/ipykernel_3058894/1073049199.py:18: RuntimeWarning: Invalid tag with only 0/16 bytes at position 51150114 in file /home/khoahd/bci-competition/data/raw/sub-CC410084_sflip_parc-raw.fif
#   rawdata = mne.io.read_raw_fif(rawdata_path, preload=True)
# segment samples: 750
# Total samples: 141000
# Opening raw data file data/raw/sub-CC420198_sflip_parc-raw.fif...
#     Range : 29750 ... 170249 =    119.000 ...   680.996 secs
# Ready.
# Reading 0 ... 140499  =      0.000 ...   561.996 secs...
# segment samples: 750
# Total samples: 140500
# Opening raw data file data/raw/sub-CC721891_sflip_parc-raw.fif...
#     Range : 14250 ... 155249 =     57.000 ...   620.996 secs
# Ready.
# Reading 0 ... 140999  =      0.000 ...   563.996 secs...
# segment samples: 750
# Total samples: 141000
# Opening raw data file data/raw/sub-CC721704_sflip_parc-raw.fif...
#     Range : 14500 ... 156499 =     58.000 ...   625.996 secs
# Ready.
# Reading 0 ... 141999  =      0.000 ...   567.996 secs...
# segment samples: 750
# Total samples: 142000
# Opening raw data file data/raw/sub-CC620619_sflip_parc-raw.fif...
#     Range : 17000 ... 157249 =     68.000 ...   628.996 secs
# Ready.
# Reading 0 ... 140249  =      0.000 ...   560.996 secs...
# segment samples: 750
# Total samples: 140250
# Opening raw data file data/raw/sub-CC221511_sflip_parc-raw.fif...
#     Range : 18250 ... 159499 =     73.000 ...   637.996 secs
# Ready.
# Reading 0 ... 141249  =      0.000 ...   564.996 secs...
# segment samples: 750
# Total samples: 141250
# Opening raw data file data/raw/sub-CC721504_sflip_parc-raw.fif...
#     Range : 40500 ... 184749 =    162.000 ...   738.996 secs
# Ready.
# Reading 0 ... 144249  =      0.000 ...   576.996 secs...
# segment samples: 750
# Total samples: 144250
# Opening raw data file data/raw/sub-CC320107_sflip_parc-raw.fif...
#     Range : 23250 ... 163499 =     93.000 ...   653.996 secs
# Ready.
# Reading 0 ... 140249  =      0.000 ...   560.996 secs...
# segment samples: 750
# Total samples: 140250
# Opening raw data file data/raw/sub-CC321594_sflip_parc-raw.fif...
#     Range : 6750 ... 146999 =     27.000 ...   587.996 secs
# Ready.
# Reading 0 ... 140249  =      0.000 ...   560.996 secs...
# segment samples: 750
# Total samples: 140250
# Opening raw data file data/raw/sub-CC121685_sflip_parc-raw.fif...
#     Range : 45750 ... 187999 =    183.000 ...   751.996 secs
# Ready.
# Reading 0 ... 142249  =      0.000 ...   568.996 secs...
# segment samples: 750
# Total samples: 142250
# Opening raw data file data/raw/sub-CC610040_sflip_parc-raw.fif...
#     Range : 26500 ... 169749 =    106.000 ...   678.996 secs
# Ready.
# Reading 0 ... 143249  =      0.000 ...   572.996 secs...
# segment samples: 750
# Total samples: 143250
# Opening raw data file data/raw/sub-CC520980_sflip_parc-raw.fif...
#     Range : 10750 ... 150999 =     43.000 ...   603.996 secs
# Ready.
# Reading 0 ... 140249  =      0.000 ...   560.996 secs...
# segment samples: 750
# Total samples: 140250
# Opening raw data file data/raw/sub-CC610071_sflip_parc-raw.fif...
#     Range : 19500 ... 159749 =     78.000 ...   638.996 secs
# Ready.
# Reading 0 ... 140249  =      0.000 ...   560.996 secs...
# segment samples: 750
# Total samples: 140250
# Opening raw data file data/raw/sub-CC320297_sflip_parc-raw.fif...
#     Range : 20250 ... 160999 =     81.000 ...   643.996 secs
# Ready.
# Reading 0 ... 140749  =      0.000 ...   562.996 secs...
# segment samples: 750
# Total samples: 140750
# Opening raw data file data/raw/sub-CC722542_sflip_parc-raw.fif...
#     Range : 7750 ... 149499 =     31.000 ...   597.996 secs
# Ready.
# Reading 0 ... 141749  =      0.000 ...   566.996 secs...
# segment samples: 750
# Total samples: 141750
# Opening raw data file data/raw/sub-CC720358_sflip_parc-raw.fif...
#     Range : 31500 ... 176749 =    126.000 ...   706.996 secs
# Ready.
# Reading 0 ... 145249  =      0.000 ...   580.996 secs...
# segment samples: 750
# Total samples: 145250
# Opening raw data file data/raw/sub-CC721519_sflip_parc-raw.fif...
#     Range : 25500 ... 166249 =    102.000 ...   664.996 secs
# Ready.
# Reading 0 ... 140749  =      0.000 ...   562.996 secs...
# segment samples: 750
# Total samples: 140750
# Opening raw data file data/raw/sub-CC223115_sflip_parc-raw.fif...
#     Range : 4500 ... 145249 =     18.000 ...   580.996 secs
# Ready.
# Reading 0 ... 140749  =      0.000 ...   562.996 secs...
# segment samples: 750
# Total samples: 140750
# Opening raw data file data/raw/sub-CC110087_sflip_parc-raw.fif...
#     Range : 23000 ... 163999 =     92.000 ...   655.996 secs
# Ready.
# Reading 0 ... 140999  =      0.000 ...   563.996 secs...
# segment samples: 750
# Total samples: 141000
# Opening raw data file data/raw/sub-CC720646_sflip_parc-raw.fif...
#     Range : 20750 ... 161249 =     83.000 ...   644.996 secs
# Ready.
# Reading 0 ... 140499  =      0.000 ...   561.996 secs...
# segment samples: 750
# Total samples: 140500
# Opening raw data file data/raw/sub-CC610061_sflip_parc-raw.fif...
#     Range : 22000 ... 162749 =     88.000 ...   650.996 secs
# Ready.
# Reading 0 ... 140749  =      0.000 ...   562.996 secs...
# segment samples: 750
# Total samples: 140750
# Opening raw data file data/raw/sub-CC221828_sflip_parc-raw.fif...
#     Range : 65250 ... 206999 =    261.000 ...   827.996 secs
# Ready.
# Reading 0 ... 141749  =      0.000 ...   566.996 secs...
# segment samples: 750
# Total samples: 141750
# Opening raw data file data/raw/sub-CC210023_sflip_parc-raw.fif...
#     Range : 30000 ... 171249 =    120.000 ...   684.996 secs
# Ready.
# Reading 0 ... 141249  =      0.000 ...   564.996 secs...
# segment samples: 750
# Total samples: 141250
# Opening raw data file data/raw/sub-CC410086_sflip_parc-raw.fif...
#     Range : 29250 ... 170249 =    117.000 ...   680.996 secs
# Ready.
# Reading 0 ... 140999  =      0.000 ...   563.996 secs...
# segment samples: 750
# Total samples: 141000
# Opening raw data file data/raw/sub-CC410032_sflip_parc-raw.fif...
#     Range : 16000 ... 156249 =     64.000 ...   624.996 secs
# Ready.
# Reading 0 ... 140249  =      0.000 ...   560.996 secs...
# segment samples: 750
# Total samples: 140250
# Opening raw data file data/raw/sub-CC121795_sflip_parc-raw.fif...
#     Range : 30500 ... 171249 =    122.000 ...   684.996 secs
# Ready.
# Reading 0 ... 140749  =      0.000 ...   562.996 secs...
# segment samples: 750
# Total samples: 140750
# Opening raw data file data/raw/sub-CC221487_sflip_parc-raw.fif...
#     Range : 37500 ... 177999 =    150.000 ...   711.996 secs
# Ready.
# Reading 0 ... 140499  =      0.000 ...   561.996 secs...
# segment samples: 750
# Total samples: 140500
# Opening raw data file data/raw/sub-CC110101_sflip_parc-raw.fif...
#     Range : 28500 ... 168999 =    114.000 ...   675.996 secs
# Ready.
# Reading 0 ... 140499  =      0.000 ...   561.996 secs...
# segment samples: 750
# Total samples: 140500
# Opening raw data file data/raw/sub-CC220828_sflip_parc-raw.fif...
#     Range : 44500 ... 199749 =    178.000 ...   798.996 secs
# Ready.
# Reading 0 ... 155249  =      0.000 ...   620.996 secs...
# segment samples: 750
# Total samples: 155250
# Opening raw data file data/raw/sub-CC321368_sflip_parc-raw.fif...
#     Range : 22500 ... 162749 =     90.000 ...   650.996 secs
# Ready.
# Reading 0 ... 140249  =      0.000 ...   560.996 secs...
# segment samples: 750
# Total samples: 140250
# Opening raw data file data/raw/sub-CC610050_sflip_parc-raw.fif...
#     Range : 24750 ... 165999 =     99.000 ...   663.996 secs
# Ready.
# Reading 0 ... 141249  =      0.000 ...   564.996 secs...
# segment samples: 750
# Total samples: 141250
# Opening raw data file data/raw/sub-CC510629_sflip_parc-raw.fif...
#     Range : 12500 ... 152999 =     50.000 ...   611.996 secs
# Ready.
# Reading 0 ... 140499  =      0.000 ...   561.996 secs...
# segment samples: 750
# Total samples: 140500
# Opening raw data file data/raw/sub-CC420149_sflip_parc-raw.fif...
#     Range : 27250 ... 168249 =    109.000 ...   672.996 secs
# Ready.
# Reading 0 ... 140999  =      0.000 ...   563.996 secs...
# segment samples: 750
# Total samples: 141000
# Opening raw data file data/raw/sub-CC410177_sflip_parc-raw.fif...
#     Range : 10500 ... 150999 =     42.000 ...   603.996 secs
# Ready.
# Reading 0 ... 140499  =      0.000 ...   561.996 secs...
# segment samples: 750
# Total samples: 140500
# Opening raw data file data/raw/sub-CC712027_sflip_parc-raw.fif...
#     Range : 36000 ... 171999 =    144.000 ...   687.996 secs
# Ready.
# Reading 0 ... 135999  =      0.000 ...   543.996 secs...
# segment samples: 750
# Total samples: 136000
# Opening raw data file data/raw/sub-CC720103_sflip_parc-raw.fif...
#     Range : 32000 ... 173249 =    128.000 ...   692.996 secs
# Ready.
# Reading 0 ... 141249  =      0.000 ...   564.996 secs...
# segment samples: 750
# Total samples: 141250
# Opening raw data file data/raw/sub-CC420094_sflip_parc-raw.fif...
#     Range : 4500 ... 168499 =     18.000 ...   673.996 secs
# Ready.
# Reading 0 ... 163999  =      0.000 ...   655.996 secs...
# segment samples: 750
# Total samples: 164000
# Opening raw data file data/raw/sub-CC110126_sflip_parc-raw.fif...
#     Range : 19500 ... 159749 =     78.000 ...   638.996 secs
# Ready.
# Reading 0 ... 140249  =      0.000 ...   560.996 secs...
# segment samples: 750
# Total samples: 140250
# Opening raw data file data/raw/sub-CC520175_sflip_parc-raw.fif...
#     Range : 10500 ... 150749 =     42.000 ...   602.996 secs
# Ready.
# Reading 0 ... 140249  =      0.000 ...   560.996 secs...
# segment samples: 750
# Total samples: 140250
# Opening raw data file data/raw/sub-CC110411_sflip_parc-raw.fif...
#     Range : 9750 ... 154499 =     39.000 ...   617.996 secs
# Ready.
# Reading 0 ... 144749  =      0.000 ...   578.996 secs...
# segment samples: 750
# Total samples: 144750
# Opening raw data file data/raw/sub-CC310256_sflip_parc-raw.fif...
#     Range : 24250 ... 166749 =     97.000 ...   666.996 secs
# Ready.
# Reading 0 ... 142499  =      0.000 ...   569.996 secs...
# segment samples: 750
# Total samples: 142500
# Opening raw data file data/raw/sub-CC620793_sflip_parc-raw.fif...
#     Range : 21750 ... 162249 =     87.000 ...   648.996 secs
# Ready.
# Reading 0 ... 140499  =      0.000 ...   561.996 secs...
# segment samples: 750
# Total samples: 140500
# Opening raw data file data/raw/sub-CC110056_sflip_parc-raw.fif...
#     Range : 3750 ... 143999 =     15.000 ...   575.996 secs
# Ready.
# Reading 0 ... 140249  =      0.000 ...   560.996 secs...
# segment samples: 750
# Total samples: 140250
# Opening raw data file data/raw/sub-CC120049_sflip_parc-raw.fif...
#     Range : 29500 ... 170499 =    118.000 ...   681.996 secs
# Ready.
# Reading 0 ... 140999  =      0.000 ...   563.996 secs...
# segment samples: 750
# Total samples: 141000
# Opening raw data file data/raw/sub-CC210148_sflip_parc-raw.fif...
#     Range : 27500 ... 167999 =    110.000 ...   671.996 secs
# Ready.
# Reading 0 ... 140499  =      0.000 ...   561.996 secs...
# segment samples: 750
# Total samples: 140500
# Opening raw data file data/raw/sub-CC321585_sflip_parc-raw.fif...
#     Range : 5750 ... 146249 =     23.000 ...   584.996 secs
# Ready.
# Reading 0 ... 140499  =      0.000 ...   561.996 secs...
# segment samples: 750
# Total samples: 140500
# Opening raw data file data/raw/sub-CC710429_sflip_parc-raw.fif...
#     Range : 14500 ... 156249 =     58.000 ...   624.996 secs
# Ready.
# Reading 0 ... 141749  =      0.000 ...   566.996 secs...
# segment samples: 750
# Total samples: 141750
# Opening raw data file data/raw/sub-CC620592_sflip_parc-raw.fif...
#     Range : 57750 ... 198749 =    231.000 ...   794.996 secs
# Ready.
# Reading 0 ... 140999  =      0.000 ...   563.996 secs...
# segment samples: 750
# Total samples: 141000
# Opening raw data file data/raw/sub-CC320321_sflip_parc-raw.fif...
#     Range : 39750 ... 181499 =    159.000 ...   725.996 secs
# Ready.
# Reading 0 ... 141749  =      0.000 ...   566.996 secs...
# segment samples: 750
# Total samples: 141750
# Opening raw data file data/raw/sub-CC310008_sflip_parc-raw.fif...
#     Range : 21000 ... 167499 =     84.000 ...   669.996 secs
# Ready.
# Reading 0 ... 146499  =      0.000 ...   585.996 secs...
# segment samples: 750
# Total samples: 146500
# Opening raw data file data/raw/sub-CC510392_sflip_parc-raw.fif...
#     Range : 5500 ... 145499 =     22.000 ...   581.996 secs
# Ready.
# Reading 0 ... 139999  =      0.000 ...   559.996 secs...
# segment samples: 750
# Total samples: 140000
# Opening raw data file data/raw/sub-CC222185_sflip_parc-raw.fif...
#     Range : 11500 ... 151999 =     46.000 ...   607.996 secs
# Ready.
# Reading 0 ... 140499  =      0.000 ...   561.996 secs...
# segment samples: 750
# Total samples: 140500
# Opening raw data file data/raw/sub-CC721894_sflip_parc-raw.fif...
#     Range : 35500 ... 184249 =    142.000 ...   736.996 secs
# Ready.
# Reading 0 ... 148749  =      0.000 ...   594.996 secs...
# segment samples: 750
# Total samples: 148750
# Opening raw data file data/raw/sub-CC310214_sflip_parc-raw.fif...
#     Range : 18500 ... 159999 =     74.000 ...   639.996 secs
# Ready.
# Reading 0 ... 141499  =      0.000 ...   565.996 secs...
# segment samples: 750
# Total samples: 141500
# Opening raw data file data/raw/sub-CC221740_sflip_parc-raw.fif...
#     Range : 4250 ... 144999 =     17.000 ...   579.996 secs
# Ready.
# Reading 0 ... 140749  =      0.000 ...   562.996 secs...
# segment samples: 750
# Total samples: 140750
# Opening raw data file data/raw/sub-CC420091_sflip_parc-raw.fif...
#     Range : 23500 ... 163999 =     94.000 ...   655.996 secs
# Ready.
# Reading 0 ... 140499  =      0.000 ...   561.996 secs...
# segment samples: 750
# Total samples: 140500
# Opening raw data file data/raw/sub-CC120166_sflip_parc-raw.fif...
#     Range : 23750 ... 164499 =     95.000 ...   657.996 secs
# Ready.
# Reading 0 ... 140749  =      0.000 ...   562.996 secs...
# segment samples: 750
# Total samples: 140750
# Opening raw data file data/raw/sub-CC310129_sflip_parc-raw.fif...
#     Range : 20750 ... 162499 =     83.000 ...   649.996 secs
# Ready.
# Reading 0 ... 141749  =      0.000 ...   566.996 secs...
# segment samples: 750
# Total samples: 141750
# Opening raw data file data/raw/sub-CC721532_sflip_parc-raw.fif...
#     Range : 32500 ... 174249 =    130.000 ...   696.996 secs
# Ready.
# Reading 0 ... 141749  =      0.000 ...   566.996 secs...
# segment samples: 750
# Total samples: 141750
# Opening raw data file data/raw/sub-CC620284_sflip_parc-raw.fif...
#     Range : 5500 ... 146749 =     22.000 ...   586.996 secs
# Ready.
# Reading 0 ... 141249  =      0.000 ...   564.996 secs...
# segment samples: 750
# Total samples: 141250
# Opening raw data file data/raw/sub-CC210088_sflip_parc-raw.fif...
#     Range : 30000 ... 173249 =    120.000 ...   692.996 secs
# Ready.
# Reading 0 ... 143249  =      0.000 ...   572.996 secs...
# segment samples: 750
# Total samples: 143250
# Opening raw data file data/raw/sub-CC720986_sflip_parc-raw.fif...
#     Range : 12500 ... 152999 =     50.000 ...   611.996 secs
# Ready.
# Reading 0 ... 140499  =      0.000 ...   561.996 secs...
# segment samples: 750
# Total samples: 140500
# Opening raw data file data/raw/sub-CC110037_sflip_parc-raw.fif...
#     Range : 5000 ... 145499 =     20.000 ...   581.996 secs
# Ready.
# Reading 0 ... 140499  =      0.000 ...   561.996 secs...
# segment samples: 750
# Total samples: 140500
# Opening raw data file data/raw/sub-CC222555_sflip_parc-raw.fif...
#     Range : 47000 ... 187999 =    188.000 ...   751.996 secs
# Ready.
# Reading 0 ... 140999  =      0.000 ...   563.996 secs...
# segment samples: 750
# Total samples: 141000
# Opening raw data file data/raw/sub-CC620444_sflip_parc-raw.fif...
#     Range : 20250 ... 156499 =     81.000 ...   625.996 secs
# Ready.
# Reading 0 ... 136249  =      0.000 ...   544.996 secs...
# segment samples: 750
# Total samples: 136250
# Opening raw data file data/raw/sub-CC510208_sflip_parc-raw.fif...
#     Range : 43250 ... 183749 =    173.000 ...   734.996 secs
# Ready.
# Reading 0 ... 140499  =      0.000 ...   561.996 secs...
# segment samples: 750
# Total samples: 140500
# Opening raw data file data/raw/sub-CC510076_sflip_parc-raw.fif...
#     Range : 18500 ... 159249 =     74.000 ...   636.996 secs
# Ready.
# Reading 0 ... 140749  =      0.000 ...   562.996 secs...
# segment samples: 750
# Total samples: 140750
# Opening raw data file data/raw/sub-CC520247_sflip_parc-raw.fif...
#     Range : 34750 ... 176999 =    139.000 ...   707.996 secs
# Ready.
# Reading 0 ... 142249  =      0.000 ...   568.996 secs...
# segment samples: 750
# Total samples: 142250
# Opening raw data file data/raw/sub-CC410354_sflip_parc-raw.fif...
#     Range : 19000 ... 159749 =     76.000 ...   638.996 secs
# Ready.
# Reading 0 ... 140749  =      0.000 ...   562.996 secs...
# segment samples: 750
# Total samples: 140750
# Opening raw data file data/raw/sub-CC321595_sflip_parc-raw.fif...
#     Range : 15250 ... 156249 =     61.000 ...   624.996 secs
# Ready.
# Reading 0 ... 140999  =      0.000 ...   563.996 secs...
# segment samples: 750
# Total samples: 141000
# Opening raw data file data/raw/sub-CC610046_sflip_parc-raw.fif...
#     Range : 7750 ... 148749 =     31.000 ...   594.996 secs
# Ready.
# Reading 0 ... 140999  =      0.000 ...   563.996 secs...
# segment samples: 750
# Total samples: 141000
# Opening raw data file data/raw/sub-CC723395_sflip_parc-raw.fif...
#     Range : 4000 ... 143999 =     16.000 ...   575.996 secs
# Ready.
# Reading 0 ... 139999  =      0.000 ...   559.996 secs...
# segment samples: 750
# Total samples: 140000
# Opening raw data file data/raw/sub-CC120120_sflip_parc-raw.fif...
#     Range : 23000 ... 163749 =     92.000 ...   654.996 secs
# Ready.
# Reading 0 ... 140749  =      0.000 ...   562.996 secs...
# segment samples: 750
# Total samples: 140750
# Opening raw data file data/raw/sub-CC321506_sflip_parc-raw.fif...
#     Range : 4250 ... 147499 =     17.000 ...   589.996 secs
# Ready.
# Reading 0 ... 143249  =      0.000 ...   572.996 secs...
# segment samples: 750
# Total samples: 143250
# Opening raw data file data/raw/sub-CC510256_sflip_parc-raw.fif...
#     Range : 44000 ... 185999 =    176.000 ...   743.996 secs
# Ready.
# Reading 0 ... 141999  =      0.000 ...   567.996 secs...
# segment samples: 750
# Total samples: 142000
# Opening raw data file data/raw/sub-CC110606_sflip_parc-raw.fif...
#     Range : 9750 ... 154499 =     39.000 ...   617.996 secs
# Ready.
# Reading 0 ... 144749  =      0.000 ...   578.996 secs...
# segment samples: 750
# Total samples: 144750
# Opening raw data file data/raw/sub-CC420173_sflip_parc-raw.fif...
#     Range : 13250 ... 158749 =     53.000 ...   634.996 secs
# Ready.
# Reading 0 ... 145499  =      0.000 ...   581.996 secs...
# segment samples: 750
# Total samples: 145500
# Opening raw data file data/raw/sub-CC510163_sflip_parc-raw.fif...
#     Range : 24750 ... 165499 =     99.000 ...   661.996 secs
# Ready.
# Reading 0 ... 140749  =      0.000 ...   562.996 secs...
# segment samples: 750
# Total samples: 140750
# Opening raw data file data/raw/sub-CC510242_sflip_parc-raw.fif...
#     Range : 3500 ... 144249 =     14.000 ...   576.996 secs
# Ready.
# Reading 0 ... 140749  =      0.000 ...   562.996 secs...
# segment samples: 750
# Total samples: 140750
# Opening raw data file data/raw/sub-CC510474_sflip_parc-raw.fif...
#     Range : 39000 ... 179999 =    156.000 ...   719.996 secs
# Ready.
# Reading 0 ... 140999  =      0.000 ...   563.996 secs...
# segment samples: 750
# Total samples: 141000
# Opening raw data file data/raw/sub-CC710494_sflip_parc-raw.fif...
#     Range : 18750 ... 159499 =     75.000 ...   637.996 secs
# Ready.
# Reading 0 ... 140749  =      0.000 ...   562.996 secs...
# segment samples: 750
# Total samples: 140750
# Opening raw data file data/raw/sub-CC310051_sflip_parc-raw.fif...
#     Range : 17500 ... 158249 =     70.000 ...   632.996 secs
# Ready.
# Reading 0 ... 140749  =      0.000 ...   562.996 secs...
# segment samples: 750
# Total samples: 140750
# Opening raw data file data/raw/sub-CC420261_sflip_parc-raw.fif...
#     Range : 4250 ... 144749 =     17.000 ...   578.996 secs
# Ready.
# Reading 0 ... 140499  =      0.000 ...   561.996 secs...
# segment samples: 750
# Total samples: 140500
# Opening raw data file data/raw/sub-CC120550_sflip_parc-raw.fif...
#     Range : 21000 ... 160999 =     84.000 ...   643.996 secs
# Ready.
# Reading 0 ... 139999  =      0.000 ...   559.996 secs...
# segment samples: 750
# Total samples: 140000
# Opening raw data file data/raw/sub-CC510115_sflip_parc-raw.fif...
#     Range : 4500 ... 145249 =     18.000 ...   580.996 secs
# Ready.
# Reading 0 ... 140749  =      0.000 ...   562.996 secs...
# segment samples: 750
# Total samples: 140750
# Opening raw data file data/raw/sub-CC222258_sflip_parc-raw.fif...
#     Range : 33750 ... 175249 =    135.000 ...   700.996 secs
# Ready.
# Reading 0 ... 141499  =      0.000 ...   565.996 secs...
# segment samples: 750
# Total samples: 141500
# Opening raw data file data/raw/sub-CC510086_sflip_parc-raw.fif...
#     Range : 14250 ... 154499 =     57.000 ...   617.996 secs
# Ready.
# Reading 0 ... 140249  =      0.000 ...   560.996 secs...
# segment samples: 750
# Total samples: 140250
# Opening raw data file data/raw/sub-CC711035_sflip_parc-raw.fif...
#     Range : 12750 ... 148249 =     51.000 ...   592.996 secs
# Ready.
# Reading 0 ... 135499  =      0.000 ...   541.996 secs...
# segment samples: 750
# Total samples: 135500
# Opening raw data file data/raw/sub-CC120065_sflip_parc-raw.fif...
#     Range : 23750 ... 164749 =     95.000 ...   658.996 secs
# Ready.
# Reading 0 ... 140999  =      0.000 ...   563.996 secs...
# segment samples: 750
# Total samples: 141000
# Opening raw data file data/raw/sub-CC410182_sflip_parc-raw.fif...
#     Range : 3750 ... 158249 =     15.000 ...   632.996 secs
# Ready.
# Reading 0 ... 154499  =      0.000 ...   617.996 secs...
# segment samples: 750
# Total samples: 154500
# Opening raw data file data/raw/sub-CC112141_sflip_parc-raw.fif...
#     Range : 15000 ... 155999 =     60.000 ...   623.996 secs
# Ready.
# Reading 0 ... 140999  =      0.000 ...   563.996 secs...
# segment samples: 750
# Total samples: 141000
# Opening raw data file data/raw/sub-CC320893_sflip_parc-raw.fif...
#     Range : 4000 ... 145249 =     16.000 ...   580.996 secs
# Ready.
# Reading 0 ... 141249  =      0.000 ...   564.996 secs...
# segment samples: 750
# Total samples: 141250
# Opening raw data file data/raw/sub-CC120218_sflip_parc-raw.fif...
#     Range : 10000 ... 150499 =     40.000 ...   601.996 secs
# Ready.
# Reading 0 ... 140499  =      0.000 ...   561.996 secs...
# segment samples: 750
# Total samples: 140500
# Opening raw data file data/raw/sub-CC120764_sflip_parc-raw.fif...
#     Range : 49500 ... 189499 =    198.000 ...   757.996 secs
# Ready.
# Reading 0 ... 139999  =      0.000 ...   559.996 secs...
# segment samples: 750
# Total samples: 140000
# Opening raw data file data/raw/sub-CC610405_sflip_parc-raw.fif...
#     Range : 10750 ... 151249 =     43.000 ...   604.996 secs
# Ready.
# Reading 0 ... 140499  =      0.000 ...   561.996 secs...
# segment samples: 750
# Total samples: 140500
# Opening raw data file data/raw/sub-CC720188_sflip_parc-raw.fif...
#     Range : 6000 ... 147499 =     24.000 ...   589.996 secs
# Ready.
# Reading 0 ... 141499  =      0.000 ...   565.996 secs...
# segment samples: 750
# Total samples: 141500
# Opening raw data file data/raw/sub-CC510039_sflip_parc-raw.fif...
#     Range : 20250 ... 161499 =     81.000 ...   645.996 secs
# Ready.
# Reading 0 ... 141249  =      0.000 ...   564.996 secs...
# segment samples: 750
# Total samples: 141250
# Opening raw data file data/raw/sub-CC120008_sflip_parc-raw.fif...
#     Range : 25250 ... 165999 =    101.000 ...   663.996 secs
# Ready.
# Reading 0 ... 140749  =      0.000 ...   562.996 secs...
# segment samples: 750
# Total samples: 140750
# Opening raw data file data/raw/sub-CC321899_sflip_parc-raw.fif...
#     Range : 5750 ... 146499 =     23.000 ...   585.996 secs
# Ready.
# Reading 0 ... 140749  =      0.000 ...   562.996 secs...
# segment samples: 750
# Total samples: 140750
# Opening raw data file data/raw/sub-CC120061_sflip_parc-raw.fif...
#     Range : 27500 ... 168749 =    110.000 ...   674.996 secs
# Ready.
# Reading 0 ... 141249  =      0.000 ...   564.996 secs...
# segment samples: 750
# Total samples: 141250
# Opening raw data file data/raw/sub-CC110319_sflip_parc-raw.fif...
#     Range : 18500 ... 158999 =     74.000 ...   635.996 secs
# Ready.
# Reading 0 ... 140499  =      0.000 ...   561.996 secs...
# segment samples: 750
# Total samples: 140500
# Opening raw data file data/raw/sub-CC110174_sflip_parc-raw.fif...
#     Range : 12250 ... 152749 =     49.000 ...   610.996 secs
# Ready.
# Reading 0 ... 140499  =      0.000 ...   561.996 secs...
# segment samples: 750
# Total samples: 140500
# Opening raw data file data/raw/sub-CC121411_sflip_parc-raw.fif...
#     Range : 38250 ... 179749 =    153.000 ...   718.996 secs
# Ready.
# Reading 0 ... 141499  =      0.000 ...   565.996 secs...
# segment samples: 750
# Total samples: 141500
# Opening raw data file data/raw/sub-CC721224_sflip_parc-raw.fif...
#     Range : 25750 ... 172249 =    103.000 ...   688.996 secs
# Ready.
# Reading 0 ... 146499  =      0.000 ...   585.996 secs...
# segment samples: 750
# Total samples: 146500
# Opening raw data file data/raw/sub-CC420776_sflip_parc-raw.fif...
#     Range : 31250 ... 171999 =    125.000 ...   687.996 secs
# Ready.
# Reading 0 ... 140749  =      0.000 ...   562.996 secs...
# segment samples: 750
# Total samples: 140750
# Opening raw data file data/raw/sub-CC310052_sflip_parc-raw.fif...
#     Range : 36750 ... 177749 =    147.000 ...   710.996 secs
# Ready.
# Reading 0 ... 140999  =      0.000 ...   563.996 secs...
# segment samples: 750
# Total samples: 141000
# Opening raw data file data/raw/sub-CC620479_sflip_parc-raw.fif...
#     Range : 20250 ... 160499 =     81.000 ...   641.996 secs
# Ready.
# Reading 0 ... 140249  =      0.000 ...   560.996 secs...
# segment samples: 750
# Total samples: 140250
# Opening raw data file data/raw/sub-CC510226_sflip_parc-raw.fif...
#     Range : 48500 ... 190249 =    194.000 ...   760.996 secs
# Ready.
# Reading 0 ... 141749  =      0.000 ...   566.996 secs...
# segment samples: 750
# Total samples: 141750
# Opening raw data file data/raw/sub-CC620785_sflip_parc-raw.fif...
#     Range : 17250 ... 157999 =     69.000 ...   631.996 secs
# Ready.
# Reading 0 ... 140749  =      0.000 ...   562.996 secs...
# segment samples: 750
# Total samples: 140750
# Opening raw data file data/raw/sub-CC410040_sflip_parc-raw.fif...
#     Range : 4750 ... 144999 =     19.000 ...   579.996 secs
# Ready.
# Reading 0 ... 140249  =      0.000 ...   560.996 secs...
# segment samples: 750
# Total samples: 140250

# %%
num_epochs = 20
learning_rate = 0.001
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = EEGNet().to(device)
criterion = nn.L1Loss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

train_losses = []
validation_losses = []

for epoch in range(num_epochs):
    model.train()
    train_loss = 0.0    
    for i, data in enumerate(train_loader, 0):
        inputs, labels = data
        inputs = inputs.unsqueeze(1).permute(0, 1, 3, 2).to(device)
        labels = labels.unsqueeze(1).to(device)
    
        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs, labels)
        
        loss.backward()
        optimizer.step()

        train_loss += loss.item()

    model.eval()
    correct = 0
    total = 0
    validation_loss = 0.0
    with torch.no_grad():
        for data in test_loader:
            inputs, labels = data
            inputs = inputs.unsqueeze(1).permute(0, 1, 3, 2).to(device)
            labels = labels.unsqueeze(1).to(device)


            outputs = model(inputs)
            loss = criterion(outputs, labels)
            validation_loss += loss.item()
            total += labels.size(0)

    print(f'Epoch {epoch+1}/{num_epochs}, Training Loss: {train_loss/len(train_loader)}, Validation Loss: {validation_loss/len(test_loader)}')
    train_losses.append(train_loss/len(train_loader))
    validation_losses.append(validation_loss/len(test_loader))

    model.train()

print('Finished Training')
# Out:
# Epoch 1/20, Training Loss: 50.06726532408645, Validation Loss: 49.05195320977105
# Epoch 2/20, Training Loss: 50.164938921368986, Validation Loss: 49.05733557807075
# Epoch 3/20, Training Loss: 50.14719420704762, Validation Loss: 49.05204806857639
# Epoch 4/20, Training Loss: 50.11443326726306, Validation Loss: 49.05568449232313
# Epoch 5/20, Training Loss: 50.128919590784854, Validation Loss: 49.06312950981988
# Epoch 6/20, Training Loss: 50.110126559294805, Validation Loss: 49.06112255520291
# Epoch 7/20, Training Loss: 50.0897216796875, Validation Loss: 49.06508517795139
# Epoch 8/20, Training Loss: 50.094015153426696, Validation Loss: 49.05911560058594
# Epoch 9/20, Training Loss: 50.170245740666736, Validation Loss: 49.0503414577908
# Epoch 10/20, Training Loss: 50.09830764685263, Validation Loss: 49.056429375542535
# Epoch 11/20, Training Loss: 50.13641941347602, Validation Loss: 49.04831127590603
# Epoch 12/20, Training Loss: 50.06662920733404, Validation Loss: 49.05882746378581
# Epoch 13/20, Training Loss: 50.13427024713442, Validation Loss: 49.05357911851671
# Epoch 14/20, Training Loss: 50.112796783447266, Validation Loss: 49.04975297715929
# Epoch 15/20, Training Loss: 50.138565020854244, Validation Loss: 49.068002149793834
# Epoch 16/20, Training Loss: 50.12138618170882, Validation Loss: 49.05568245781792
# Epoch 17/20, Training Loss: 50.141249139881666, Validation Loss: 49.050093502468535
# Epoch 18/20, Training Loss: 50.07146038289843, Validation Loss: 49.05728505452474
# Epoch 19/20, Training Loss: 50.120849332329946, Validation Loss: 49.060269843207465
# Epoch 20/20, Training Loss: 50.167017292044015, Validation Loss: 49.06407589382596
# Finished Training
